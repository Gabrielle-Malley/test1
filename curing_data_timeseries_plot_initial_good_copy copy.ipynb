# %% [markdown]
# # Read Me
#
# Module Name: Grassland Curing Data Time Series
#
# Date of creation: 17/05/2022
#
# Name of creator of module : GM
#
# History of modification:
#     Last modification: 19/05
#     Modifications: Raw script to Juypter notebook
#     - added a loop for multiple fwd and changes a few variable names
#
# Summary of what the module does:
#
# Reads fire weather district (fwd) shape files as a dataframe
#
# Reads in avaliable MODIS curing data from 2015-2020
#
# Loops over the day of year, for each year every 8 days
#
# Loop opens MODIS data using xarray (xr) and clips array by the fire weather district shape files
#
# Generates a basic plot for the array for curing data over time
#
# typical calls: file_path = '/g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/'
#
# file path = curing-filled_modis-mapvictoria_8day_500m_vic_%s.tif
#
# fwd_shapefile_path = '/g/data/ct18/dw4060/viirs/inputfiles/boundaries/FWFDistricts_MapID_WGS84_May2022.shp'

# %% [markdown]
# # Packages

# %%
import os, sys
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import geopandas
import datetime
import glob
import os
import xarray as xr

# %% [markdown]
# # Read data

# %%
#read in fire weather district shape files (fwd)
fwd_shapefile_path = '/g/data/ct18/dw4060/viirs/inputfiles/boundaries/FWFDistricts_MapID_WGS84_May2022.shp'
df = geopandas.read_file(fwd_shapefile_path)
#print(type(df))
#print(df.head(n=10))
#print(df.tail(n=10))
#read in MODIS curing data
file_path = '/g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/'

# %% [markdown]
# # Constants

# %%
fwd_districts = ["Wimmera", "Mallee", "South West", "Northern Country", "North Central", "Central", "North East", "West and South Gippsland", "East Gippsland"]

fwd_geometry = df[df['DIST_NAME'] == 'Mallee'].geometry.values

#MODIS data
year = 2015
t0 = datetime.datetime(year, 7, 1)
time_array = []
mean_curing_value = []

# %% [markdown]
# # Analysis and loops

# %%
for doy in range(0, 365, 8):
    current_date = t0 + datetime.timedelta(days=doy)
    fns = glob.glob(os.path.join(file_path, "curing-filled_modis-mapvictoria_8day_500m_vic_%s.tif" % current_date.strftime('%Y%m%d')))
    print("fns", fns)
    #cheking file exists
    if len(fns) == 1: 
        #opening the file using xr
        ds = xr.open_dataset(fns[0])
        #taking the grasskand cuirng data (gci) and clipping I with the geometry of the fwds
        gci_clipped_to_fwd = ds.rio.clip(fwd_geometry, df.crs)
        #calculte the mean for the clipped gci
        print(doy, current_date, fns[0], gci_clipped_to_fwd.mean())
        #determine mean curing values for the Mallee fwd and structure them as an array starting from the first idex
        mean_curing_value.append(gci_clipped_to_fwd.mean().to_array().values[0])
        #add current date variable to the time arrazy variable 
        time_array.append(current_date)
        #print('mean_curing_value', mean_curing_value)
        #print('time_array', time_array)
# Out:
# 0 2015-07-01 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20150701.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 14.41
# 8 2015-07-09 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20150709.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 12.53
# 16 2015-07-17 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20150717.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 11.12
# 24 2015-07-25 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20150725.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 12.08
# 32 2015-08-02 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20150802.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 14.9
# 40 2015-08-10 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20150810.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 15.87
# 48 2015-08-18 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20150818.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 16.73
# 56 2015-08-26 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20150826.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 17.52
# 64 2015-09-03 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20150903.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 13.8
# 72 2015-09-11 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20150911.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 11.61
# 80 2015-09-19 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20150919.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 16.68
# 104 2015-10-13 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20151013.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 24.4
# 112 2015-10-21 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20151021.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 23.54
# 120 2015-10-29 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20151029.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 22.47
# 128 2015-11-06 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20151106.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 20.61
# 136 2015-11-14 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20151114.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 21.85
# 144 2015-11-22 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20151122.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 25.13
# 152 2015-11-30 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20151130.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 26.0
# 160 2015-12-08 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20151208.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 26.49
# 168 2015-12-16 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20151216.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 26.86
# 176 2015-12-24 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20151224.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 30.94
# 184 2016-01-01 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160101.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 31.62
# 192 2016-01-09 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160109.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 29.9
# 200 2016-01-17 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160117.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 26.63
# 208 2016-01-25 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160125.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 26.24
# 216 2016-02-02 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160202.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 21.57
# 224 2016-02-10 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160210.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 22.87
# 232 2016-02-18 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160218.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 22.31
# 248 2016-03-05 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160305.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 26.66
# 256 2016-03-13 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160313.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 21.67
# 264 2016-03-21 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160321.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 21.01
# 272 2016-03-29 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160329.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 18.38
# 280 2016-04-06 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160406.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 18.13
# 296 2016-04-22 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160422.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 19.37
# 304 2016-04-30 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160430.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 17.24
# 312 2016-05-08 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160508.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 17.21
# 320 2016-05-16 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160516.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 16.85
# 328 2016-05-24 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160524.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 15.2
# 336 2016-06-01 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160601.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 15.87
# 344 2016-06-09 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160609.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 14.16
# 352 2016-06-17 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160617.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 14.73
# 360 2016-06-25 00:00:00 /g/data/ct18/Historical_Curing/BOM_raw_daily_input_for_VISCA/unzipped/vic/curing-filled_modis-mapvictoria_8day_500m_vic_20160625.tif <xarray.Dataset>
# Dimensions:      ()
# Coordinates:
#     spatial_ref  int64 0
# Data variables:
#     band_data    float32 15.3

# %% [markdown]
# # Plots

# %%
#plotting out array (you can also stor you plot as a variable/object to manipulate it further)
plt.plot(time_array,mean_curing_value)

plt.title('Mallee')
plt.xlabel('Time (Year-Month)')
plt.ylabel('Grassland Curing Value (%)')
plt.show()
#plt.savefig("curing_timeline.png")

# %%
fwd_districts = ["Wimmera", "Mallee", "South West", "Northern Country", "North Central", "Central", "North East", "West and South Gippsland", "East Gippsland"]
total_data = []


#fwd_directory =[""]
#year = 2000
#for i in range(len(fwd_directory))


for name in range(len(fwd_districts)):
    fwd_geometry = df[df['DIST_NAME'] == fwd_districts[name]].geometry.values
    year = 2015
    t0 = datetime.datetime(year, 7, 1)
    time_array = []
    mean_curing_value = []
    for doy in range(0, 365, 8):
        current_date = t0 + datetime.timedelta(days=doy)
        fns = glob.glob(os.path.join(file_path, "curing-filled_modis-mapvictoria_8day_500m_vic_%s.tif" % current_date.strftime('%Y%m%d')))
        #print("fns", fns)
    #cheking file exists
        if len(fns) == 1: 
        #opening the file using xr
            ds = xr.open_dataset(fns[0])
            #taking the grassland curing data (gci) and clipping I with the geometry of the fwds
            gci_clipped_to_fwd = ds.rio.clip(fwd_geometry, df.crs)
            #calculte the mean for the clipped gci
            
            #determine mean curing values for the all the fwds and structure them as an array starting from the first idex
            mean_curing_value.append(gci_clipped_to_fwd.mean().to_array().values[0])
            #add current date variable to the time arrazy variable 
            time_array.append(current_date)
            

#plotting out array (you can also stor you plot as a variable/object to manipulate it further)
    plt.plot(time_array,mean_curing_value)

    plt.title(fwd_districts[name])
    plt.xlabel('Time (Year-Month)')
    plt.ylabel('Mean Grassland Curing Value (%)')
    plt.show()
    total_data.append([time_array, mean_curing_value])
#plt.savefig("curing_timeline.png")

print(total_data)
# Out:
# [[[datetime.datetime(2015, 7, 1, 0, 0), datetime.datetime(2015, 7, 9, 0, 0), datetime.datetime(2015, 7, 17, 0, 0), datetime.datetime(2015, 7, 25, 0, 0), datetime.datetime(2015, 8, 2, 0, 0), datetime.datetime(2015, 8, 10, 0, 0), datetime.datetime(2015, 8, 18, 0, 0), datetime.datetime(2015, 8, 26, 0, 0), datetime.datetime(2015, 9, 3, 0, 0), datetime.datetime(2015, 9, 11, 0, 0), datetime.datetime(2015, 9, 19, 0, 0), datetime.datetime(2015, 10, 13, 0, 0), datetime.datetime(2015, 10, 21, 0, 0), datetime.datetime(2015, 10, 29, 0, 0), datetime.datetime(2015, 11, 6, 0, 0), datetime.datetime(2015, 11, 14, 0, 0), datetime.datetime(2015, 11, 22, 0, 0), datetime.datetime(2015, 11, 30, 0, 0), datetime.datetime(2015, 12, 8, 0, 0), datetime.datetime(2015, 12, 16, 0, 0), datetime.datetime(2015, 12, 24, 0, 0), datetime.datetime(2016, 1, 1, 0, 0), datetime.datetime(2016, 1, 9, 0, 0), datetime.datetime(2016, 1, 17, 0, 0), datetime.datetime(2016, 1, 25, 0, 0), datetime.datetime(2016, 2, 2, 0, 0), datetime.datetime(2016, 2, 10, 0, 0), datetime.datetime(2016, 2, 18, 0, 0), datetime.datetime(2016, 3, 5, 0, 0), datetime.datetime(2016, 3, 13, 0, 0), datetime.datetime(2016, 3, 21, 0, 0), datetime.datetime(2016, 3, 29, 0, 0), datetime.datetime(2016, 4, 6, 0, 0), datetime.datetime(2016, 4, 22, 0, 0), datetime.datetime(2016, 4, 30, 0, 0), datetime.datetime(2016, 5, 8, 0, 0), datetime.datetime(2016, 5, 16, 0, 0), datetime.datetime(2016, 5, 24, 0, 0), datetime.datetime(2016, 6, 1, 0, 0), datetime.datetime(2016, 6, 9, 0, 0), datetime.datetime(2016, 6, 17, 0, 0), datetime.datetime(2016, 6, 25, 0, 0)], [62.46253, 62.101894, 55.684895, 53.998287, 49.588932, 45.776283, 41.86478, 46.14446, 41.30689, 42.625435, 44.92234, 69.71805, 71.13249, 80.964745, 84.28718, 87.8105, 91.00586, 90.272354, 92.72287, 94.21031, 93.96566, 94.08881, 93.9058, 94.726555, 93.8227, 93.59068, 93.57298, 93.55324, 93.34525, 92.669395, 92.044716, 88.53674, 90.316086, 90.271904, 89.45716, 86.338425, 80.440186, 77.04109, 70.063034, 64.69184, 60.323875, 51.573322]], [[datetime.datetime(2015, 7, 1, 0, 0), datetime.datetime(2015, 7, 9, 0, 0), datetime.datetime(2015, 7, 17, 0, 0), datetime.datetime(2015, 7, 25, 0, 0), datetime.datetime(2015, 8, 2, 0, 0), datetime.datetime(2015, 8, 10, 0, 0), datetime.datetime(2015, 8, 18, 0, 0), datetime.datetime(2015, 8, 26, 0, 0), datetime.datetime(2015, 9, 3, 0, 0), datetime.datetime(2015, 9, 11, 0, 0), datetime.datetime(2015, 9, 19, 0, 0), datetime.datetime(2015, 10, 13, 0, 0), datetime.datetime(2015, 10, 21, 0, 0), datetime.datetime(2015, 10, 29, 0, 0), datetime.datetime(2015, 11, 6, 0, 0), datetime.datetime(2015, 11, 14, 0, 0), datetime.datetime(2015, 11, 22, 0, 0), datetime.datetime(2015, 11, 30, 0, 0), datetime.datetime(2015, 12, 8, 0, 0), datetime.datetime(2015, 12, 16, 0, 0), datetime.datetime(2015, 12, 24, 0, 0), datetime.datetime(2016, 1, 1, 0, 0), datetime.datetime(2016, 1, 9, 0, 0), datetime.datetime(2016, 1, 17, 0, 0), datetime.datetime(2016, 1, 25, 0, 0), datetime.datetime(2016, 2, 2, 0, 0), datetime.datetime(2016, 2, 10, 0, 0), datetime.datetime(2016, 2, 18, 0, 0), datetime.datetime(2016, 3, 5, 0, 0), datetime.datetime(2016, 3, 13, 0, 0), datetime.datetime(2016, 3, 21, 0, 0), datetime.datetime(2016, 3, 29, 0, 0), datetime.datetime(2016, 4, 6, 0, 0), datetime.datetime(2016, 4, 22, 0, 0), datetime.datetime(2016, 4, 30, 0, 0), datetime.datetime(2016, 5, 8, 0, 0), datetime.datetime(2016, 5, 16, 0, 0), datetime.datetime(2016, 5, 24, 0, 0), datetime.datetime(2016, 6, 1, 0, 0), datetime.datetime(2016, 6, 9, 0, 0), datetime.datetime(2016, 6, 17, 0, 0), datetime.datetime(2016, 6, 25, 0, 0)], [73.42429, 74.329666, 61.62663, 66.67119, 62.545696, 60.183113, 54.809834, 59.527493, 58.118614, 61.90779, 62.678036, 85.22414, 86.96115, 91.7934, 92.9003, 94.8335, 95.52317, 95.63291, 96.06802, 96.132614, 95.99798, 96.06508, 95.2792, 95.79507, 95.246445, 95.315735, 95.139725, 95.1796, 94.88662, 94.44095, 94.24152, 92.4774, 93.59162, 92.355255, 91.892494, 90.3352, 90.0 ...
